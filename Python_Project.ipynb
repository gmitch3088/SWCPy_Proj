# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
datafull = np.loadtxt(fname="solar2.txt", delimiter=" ")
datafull
# Out:
# array([ 172685.,   90103.,   45224.,  553653.,  187108.,  163409.,
#         160397.,   87347.,  522731., 1003601.,  600378.,  203286.,
#         824575., 5589938.,  554041.,  130561., 7182012.])

# %%
# %matplotlib inline
image = plt.plot(datafull)
plt.show()

# %%
datafulla = np.loadtxt(fname="solar3.txt", delimiter=" ")
datafulla
# Out:
# array([[8.11022014e+08, 7.80000000e+01, 3.64600000e+03, 1.72685000e+05],
#        [8.12111142e+08, 1.97000000e+02, 2.40800000e+03, 9.01030000e+04],
#        [9.07061702e+08, 1.39000000e+02, 2.43400000e+03, 4.52240000e+04],
#        [9.10250216e+08, 1.14000000e+02, 3.85900000e+03, 5.53653000e+05],
#        [9.10262246e+08, 3.15000000e+02, 7.23700000e+03, 1.87108000e+05],
#        [9.10270152e+08, 1.97000000e+02, 9.01600000e+03, 1.63409000e+05],
#        [9.10271014e+08, 6.14000000e+02, 1.93100000e+03, 1.60397000e+05],
#        [9.10271309e+08, 1.97000000e+02, 3.47200000e+03, 8.73470000e+04],
#        [9.10271936e+08, 2.57000000e+02, 8.00600000e+03, 5.22731000e+05],
#        [9.12101056e+08, 1.76000000e+02, 1.92910000e+04, 1.00360100e+06],
#        [9.12160125e+08, 8.31000000e+02, 4.17700000e+03, 6.00378000e+05],
#        [9.12160836e+08, 6.90000000e+01, 6.87500000e+03, 2.03286000e+05],
#        [9.12161252e+08, 1.49900000e+03, 5.72500000e+03, 8.24575000e+05],
#        [9.12190012e+08, 2.74000000e+02, 2.93570000e+04, 5.54041000e+05],
#        [9.12210921e+08, 3.73000000e+02, 2.47500000e+03, 1.30561000e+05],
#        [9.12220453e+08, 6.22000000e+02, 3.99430000e+04, 7.18201200e+06]])

# %%
newdata = datafulla[:,1:3]

# %%
print(newdata)
# Out:
# [[   78.  3646.]
#  [  197.  2408.]
#  [  139.  2434.]
#  [  114.  3859.]
#  [  315.  7237.]
#  [  197.  9016.]
#  [  614.  1931.]
#  [  197.  3472.]
#  [  257.  8006.]
#  [  176. 19291.]
#  [  831.  4177.]
#  [   69.  6875.]
#  [ 1499.  5725.]
#  [  274. 29357.]
#  [  373.  2475.]
#  [  622. 39943.]]

# %%
x, y = newdata.T
plt.scatter(x,y)

# %%
#fig = plt.figure()
#ax1 = fig.add_subplot(1, 1, 1)

fig, ax1 = plt.subplots()
x, y = newdata.T
plt.scatter(x,y, color = "green")

ax1.set_ylabel('peak')
fig.suptitle('Peaks vs. the duration of the solar flares')
    
ax1.set_xlabel('duration')

plt.show()
